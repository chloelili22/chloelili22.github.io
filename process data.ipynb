# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('Taxi_Trips (3).csv')
df
# Out:
#                                          Trip ID  \
# 0       1a90980e4da5ad6abc8b23425c985ac63d3ad114
# 1       1de10d96f620fc9ae1031694d31abea6a556ce1c
# 2       428f78e1a35d83c3189e1a63507d4c75fb6ca12d
# 3       46e245ff2bc76536c8bcd5b738c31fe9c6581390
# 4       5a4934d98b2b0afffeefecae24a0fc75f0b04c6f
# ...                                          ...
# 208686  eaffe95e68e7f8e2fde9ede97eb6197591d8a5a5
# 208687  f95bf99738ba260782dca4b5880c0ef719ce55b3
# 208688  fd35c36ae728f14d494a438964f324f98387ef45
# 208689  ff2622223d559b1e9ced20b04fd41dc4f02afa38
# 208690  bed9fdc66b90c6d34ecadf3881f9db480ccd4b27
#
#                                                   Taxi ID  \
# 0       d6fd39863cdce99011c7282605bedf70d9d059ecf0da5e...
# 1       1099c684f9da1ac1d0dd253d394f1c8dad37bc1a53d944...
# 2       9458348b38e6b327b2d8fc070b05551916fd95da48ea13...
# 3       565d45f83a15ee7d65f7e519ebd063597b2e7e4ef63090...
# 4       e11ecc8e74a2d3cbd2e9f58151ed09c81587cb491c50f6...
# ...

# %%
df1 = df[['Trip Start Timestamp','Trip Miles', 'Pickup Community Area', 'Fare', 'Tips', 'Company', 'Pickup Centroid Latitude', 'Pickup Centroid Longitude']]
df1 = df1.dropna()
df1 = df1[(df1['Trip Miles'] > 0) & (df1['Fare'] > 0) & (df1['Tips'] > 0) & (df1['Pickup Centroid Latitude'] != 0) & (df1['Pickup Centroid Longitude'] != 0)]
df1 = df1.reset_index(drop=True)
df1
# Out:
#          Trip Start Timestamp  Trip Miles  Pickup Community Area   Fare  \
# 0      03/01/2021 12:00:00 AM       14.30                   76.0  36.00
# 1      03/01/2021 12:00:00 AM        0.50                   77.0   5.25
# 2      03/01/2021 12:00:00 AM       17.10                   76.0  42.25
# 3      03/01/2021 12:00:00 AM        7.90                   76.0  21.25
# 4      03/01/2021 12:00:00 AM       13.20                   76.0  34.00
# ...                       ...         ...                    ...    ...
# 42511  03/31/2021 11:45:00 PM       17.97                   56.0  44.75
# 42512  03/31/2021 11:45:00 PM        0.40                   32.0  21.00
# 42513  03/31/2021 11:45:00 PM       18.13                   76.0  44.00
# 42514  03/31/2021 11:45:00 PM       15.00                   76.0  38.25
# 42515  03/31/2021 11:45:00 PM        2.50                   76.0   9.00
#
#         Tips                               Company  Pickup Centroid Latitude  \
# ...

# %%
df1_remd = df1.drop_duplicates(subset=['Pickup Centroid Latitude', 'Pickup Centroid Longitude'], keep='first')
df1_remd.to_csv("taxiTripsDist3.csv")

# %%
# df1.to_csv("taxiTripsinMarch.csv")

# %% [markdown]
# Taking the attributes/columns of data we need and clean data with NA in March 2021.

# %%
# df1 = df[['Trip Miles', 'Pickup Community Area', 'Fare', 'Tips', 'Company', 'Pickup Centroid Latitude', 'Pickup Centroid Longitude']]
# df1 = df1.dropna()
# df1 = df1[(df1['Trip Miles'] > 0) & (df1['Fare'] > 0) & (df1['Tips'] > 0) & (df1['Pickup Centroid Latitude'] != 0) & (df1['Pickup Centroid Longitude'] != 0)]
# df1 = df1.reset_index(drop=True)
# df1
# Out:
#        Trip Miles  Pickup Community Area   Fare   Tips  \
# 0           14.30                   76.0  36.00   8.40
# 1            0.50                   77.0   5.25   1.00
# 2           17.10                   76.0  42.25   9.30
# 3            7.90                   76.0  21.25   6.69
# 4           13.20                   76.0  34.00   7.70
# ...           ...                    ...    ...    ...
# 42511       17.97                   56.0  44.75  10.05
# 42512        0.40                   32.0  21.00   4.25
# 42513       18.13                   76.0  44.00  10.00
# 42514       15.00                   76.0  38.25   8.55
# 42515        2.50                   76.0   9.00   3.60
#
#                                     Company  Pickup Centroid Latitude  \
# 0                       Top Cab Affiliation                 41.980264
# 1                 Taxi Affiliation Services                 41.986712
# 2                 Taxi Affiliation Services                 41.980264
# ...

# %%
# df1.to_csv("taxiTrips3.csv")

# %% [markdown]
# Remove duplicate lat and long. Then, sorting the tips to get the top 20 trips with higher tips in March 2021.

# %%
df_sort = df1.drop_duplicates(subset=['Pickup Centroid Latitude', 'Pickup Centroid Longitude'], keep='first')
df_sort = df_sort.sort_values(by=['Tips'], ascending=False)
df_sort = df_sort.reset_index(drop=True)
df_sort
# Out:
#        Trip Start Timestamp  Trip Miles  Pickup Community Area   Fare   Tips  \
# 0    03/01/2021 12:00:00 AM        3.40                    8.0  12.25  50.00
# 1    03/01/2021 06:45:00 AM        0.40                   70.0   4.25  15.05
# 2    03/01/2021 10:15:00 AM       16.70                   56.0  42.50  13.90
# 3    03/21/2021 02:30:00 PM        0.50                   41.0  23.25  12.00
# 4    03/01/2021 12:15:00 AM       18.00                   76.0  44.50  10.20
# ..                      ...         ...                    ...    ...    ...
# 132  03/02/2021 12:45:00 PM       10.17                   50.0  26.75   0.07
# 133  03/02/2021 01:30:00 PM       12.11                   53.0  30.75   0.07
# 134  03/01/2021 08:00:00 AM        9.18                   41.0  25.50   0.07
# 135  03/01/2021 03:30:00 PM        9.00                   27.0  27.00   0.07
# 136  03/03/2021 01:30:00 PM        9.60                   45.0  37.75   0.01
#
# ...

# %% [markdown]
# Convert the data to 2d arrays.

# %%
# print(df_sort.values.tolist())

# %%
df2 = pd.read_csv('Taxi_Trips (4).csv')
df2
# Out:
#                                          Trip ID  \
# 0       3c5106795783d7fcc201c9ea7f7fc327f696a655
# 1       3f39c2164c7288d5e0e693e740d0f8b95f51042d
# 2       44f5c5c1071475c9d6b6470fbd1d77c65e2d8558
# 3       15807607e5de3261b1d8c085e53ea87ba0faae08
# 4       44a1c2eb9ebf4cc63d3ab7926fec4e96637e859e
# ...                                          ...
# 428590  fb8ad62d83e223af526599a028d694737983e162
# 428591  e7c44450b5bfc060de3519f2e5d0014876833c72
# 428592  f02d28c1bbf5b9c7b0ceddaab476a857acd08253
# 428593  3b3ed0e0b74f9da7c38c6f1f1a858195094621a9
# 428594  648b591859633ddf518559984329832827d29ce7
#
#                                                   Taxi ID  \
# 0       624e8f2a6af3b7f032d3c40d6f925f6fc5f0bf6a358ecc...
# 1       13c8f729e7e5a9f850e406e3b31524c6881649044dab76...
# 2       26a53f41b40ca4ec225a15ff55054c0a2d9e4a48341ce9...
# 3       af97f8e35520e11b9afbea803e78be3a641fe2b3ccea82...
# 4       ec56c095d0e5b779d527c06e9551ccb27b04c70e1b8d8e...
# ...

# %% [markdown]
# Taking the attributes/columns of data we need and clean data with NA in September 2021.

# %%
df9 = df2[['Trip Start Timestamp', 'Trip Miles', 'Pickup Community Area', 'Fare', 'Tips', 'Company', 'Pickup Centroid Latitude', 'Pickup Centroid Longitude']]
df9 = df9.dropna()
df9 = df9[(df9['Trip Miles'] > 0) & (df9['Fare'] > 0) & (df9['Tips'] > 0) & (df9['Pickup Centroid Latitude'] != 0) & (df9['Pickup Centroid Longitude'] != 0)]
df9 = df9.reset_index(drop=True)
df9
df9.to_csv("taxiTripsinSept.csv")

# %% [markdown]
# Remove duplicate lat and long. Then, sorting the tips to get the top 20 trips with higher tips in Septemeber 2021.

# %%
dfSort9 = df9.drop_duplicates(subset=['Pickup Centroid Latitude', 'Pickup Centroid Longitude'], keep='first')
dfSort9 = dfSort9.sort_values(by=['Tips'], ascending=False)
dfSort9 = dfSort9.reset_index(drop=True)
dfSort9
# Out:
#        Trip Start Timestamp  Trip Miles  Pickup Community Area   Fare   Tips  \
# 0    09/01/2021 07:15:00 AM       18.80                    8.0  46.75  20.00
# 1    09/01/2021 06:00:00 AM        0.70                   32.0  32.75  20.00
# 2    09/14/2021 11:30:00 PM        7.80                   34.0  22.00  15.00
# 3    09/01/2021 03:15:00 PM       19.54                   31.0  48.00  12.50
# 4    09/01/2021 07:30:00 AM       10.37                   16.0  26.50  12.00
# ..                      ...         ...                    ...    ...    ...
# 175  09/03/2021 01:00:00 PM        9.09                   54.0  30.00   0.07
# 176  09/03/2021 03:00:00 PM        7.95                   61.0  23.75   0.07
# 177  09/02/2021 09:30:00 AM        6.03                   68.0  17.75   0.07
# 178  09/09/2021 03:15:00 PM       18.30                   41.0  51.00   0.04
# 179  09/01/2021 12:45:00 AM       13.59                   38.0  37.00   0.04
#
# ...

# %% [markdown]
# Convert the data to 2d arrays.

# %%
# print(dfSort9.values.tolist())

# %%
df6 = pd.read_csv('Taxi_Trips (2).csv')
df6
# Out:
#                                          Trip ID  \
# 0       be3eb22cd0ad2de1c8e4a3f05a96319eddae9508
# 1       06695c7cab046f116f21cd17030ab62fcfdf866b
# 2       082d2f22a49740bd6be292097e0b504d1f9a5d14
# 3       28ff72703bc344c19d042feedea7a21dd6111e79
# 4       31ea3706b08bc01a5599269ff79eff3709149ee3
# ...                                          ...
# 332258  f0a29b31bf0c176f3bb37a7dd0ea3b73de0d93c7
# 332259  f3be21be4a77da33eec92afb9cbc1f86c51d3d04
# 332260  f5c6f72f43d60568db87fd6cdf735afd40059911
# 332261  fa6889fc563af4e708a02af78c2a9dce5a4ce878
# 332262  789dac99383ef7cb328f47231a3bb267b8a4e305
#
#                                                   Taxi ID  \
# 0       6bc9a4b2f488c8531e48dd2a8c10459515b486fc16d78a...
# 1       0aba795cd29b34ff868043bc923a341f37c4f6d7afabe4...
# 2       c4b8125a4c89c864b1f5dfc240ff17752f46dc27f574cf...
# 3       9ff153898c75dbd960a207b660a71f92f79b666dcec98e...
# 4       82bc059c3b13e97341f941d60f772ae9f83687498e91f7...
# ...

# %% [markdown]
# Taking the attributes/columns of data we need and clean data with NA in June 2021.

# %%
df6_new = df6[['Trip Start Timestamp', 'Trip Miles', 'Pickup Community Area', 'Fare', 'Tips', 'Company', 'Pickup Centroid Latitude', 'Pickup Centroid Longitude']]
df6_new = df6_new .dropna()
df6_new  = df6_new [(df6_new ['Trip Miles'] > 0) & (df6_new ['Fare'] > 0) & (df6_new ['Tips'] > 0) & (df6_new ['Pickup Centroid Latitude'] != 0) & (df6_new ['Pickup Centroid Longitude'] != 0)]
df6_new  = df6_new .reset_index(drop=True)
df6_new 
df6_new .to_csv("taxiTripsinJune.csv")

# %% [markdown]
# Remove duplicate lat and long. Then, sorting the tips to get the top 20 trips with higher tips in June 2021.

# %%
dfSort6 = df6_new.drop_duplicates(subset=['Pickup Centroid Latitude', 'Pickup Centroid Longitude'], keep='first')
dfSort6 = dfSort6.sort_values(by=['Tips'], ascending=False)
dfSort6 = dfSort6.reset_index(drop=True)
dfSort6
# Out:
#        Trip Start Timestamp  Trip Miles  Pickup Community Area   Fare   Tips  \
# 0    06/04/2021 10:00:00 AM        5.80                   23.0  17.75  81.75
# 1    06/01/2021 12:00:00 AM       30.30                   56.0  72.75  20.19
# 2    06/02/2021 06:30:00 PM       13.70                    6.0  45.25  20.00
# 3    06/15/2021 09:30:00 AM       24.30                   39.0  58.75  20.00
# 4    06/01/2021 03:30:00 PM       22.70                   10.0  57.00  16.50
# ..                      ...         ...                    ...    ...    ...
# 156  06/02/2021 01:00:00 PM        8.39                   66.0  25.00   0.07
# 157  06/01/2021 03:00:00 PM       10.95                   71.0  31.25   0.07
# 158  06/02/2021 10:00:00 AM        0.57                   29.0   5.00   0.04
# 159  06/01/2021 04:00:00 AM       13.28                   73.0  34.50   0.04
# 160  06/23/2021 11:30:00 AM        6.06                   38.0  17.75   0.04
#
# ...

# %% [markdown]
# Convert the data to 2d arrays.

# %%
print(dfSort6.values.tolist())
# Out:
# [[9.2, 76.0, 24.75, 200.0, 'Taxi Affiliation Services', 41.980264315, -87.913624596], [37.1, 76.0, 101.5, 140.0, 'Taxicab Insurance Agency, LLC', 41.97907082, -87.903039661], [1.0, 32.0, 44.25, 85.45, 'Taxi Affiliation Services', 41.880994471, -87.632746489], [5.5, 8.0, 17.5, 83.0, 'Top Cab Affiliation', 41.899602111, -87.633308037], [5.8, 23.0, 17.75, 81.75, 'Medallion Leasin', 41.900069603, -87.720918238], [16.9, 56.0, 43.5, 65.25, 'Taxi Affiliation Services', 41.79259236, -87.769615453], [11.5, 56.0, 31.0, 60.0, 'Taxicab Insurance Agency, LLC', 41.785998518, -87.750934289], [0.9, 32.0, 8.5, 58.0, 'Medallion Leasin', 41.870607372, -87.622172937], [1.6, 8.0, 7.75, 50.0, 'Taxi Affiliation Services', 41.90749193, -87.63576009], [19.8, 33.0, 53.25, 50.0, 'Taxicab Insurance Agency, LLC', 41.859349715, -87.617358006], [0.1, 6.0, 3.5, 50.0, 'Taxi Affiliation Services', 41.944226601, -87.655998182], [0.5, 32.0, 7.25, 50.0, 'Medallion Leasin', 41.878865584, -87.625192142], [39.66, 34.0, 93.
# ...
